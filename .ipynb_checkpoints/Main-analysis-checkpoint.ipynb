# %% [markdown]
# # Main analysis file for Vogelstein project

# %% [markdown]
# ## Questions

# %%
# What does "scale the data" mean? Do I want a matplotlib figure with a scaled figsize, or do I want the actual numpy data scaled?
# What dooes "levels" mean?
# How much variance is there between the two sessions this subject underwent? Is there any way to make 
# the random forest do anything but angrily say "no"?

# %% [markdown]
# ## TODOS

# %%
# TODO: scale data
# TODO: plot t=5, z slice=15 from each session (2 sessions total?)
# TODO: figure out best way to plot MRI data. Figure out if 'plot' means 'show brain structure' or 'make a graph'.
# TODO: write a loop that outputs, at slice 15, intensity values above threshold for each session.
# TODO: Figure out how to determine what threshold to use.
# TODO: figure out what 'first-order analysis' means.
# TODO: figure out how random forest classifiers work.
# TODO: learn what out-of-bag error means.
# TODO: learn what a class conditional posterior estimated random forest is.
# TODO: Slider widget that moves through time (for fun if I have time)
# TODO: Slider widget that moves through z-axis (for fun if I have time)

# %% [markdown]
# ## Get the data

# %%
import pandas as pd  # in case I need it
import numpy as np
import os
import nibabel as nib
import matplotlib.pyplot as plt
np.set_printoptions(precision=2, suppress=True)  # For clarity

# %%
mri1 = nib.load('sub-0025865_ses-1_dwi_aligned.nii')
mri2 = nib.load('sub-0025865_ses-2_dwi_aligned.nii')

# %%
mri1_data = mri1.get_data()  # Turn into numpy data. This appears to be only an axial section.
mri2_data = mri2.get_data()

# %%
mri1_fdata = mri1.get_fdata()
mri2_fdata = mri2.get_fdata()

# %% [markdown]
# ## First impressions of the data

# %%
mri1_data.shape
# Out:
# (182, 218, 182, 31)

# %%
mri1.shape  # 182x218 image size for 182 slices across 31 sessions
# Out:
# (182, 218, 182, 31)

# %%
mri1.shape == mri2.shape
# Out:
# True

# %%
hdr = mri1.header  # metadata about the image

# %%
print(hdr)  # Show me the money
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  4 182 218 182  31   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [ 1.  1.  1.  1.  1.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : -138.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'FSL5.0'
# aux_file        : b''
# qform_code      : aligned
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 90.0
# ...

# %%
hdr.get_xyzt_units()
# Time is in seconds, size units are in millimeters.
# So I think this means each of the 30 time images comprise a second, and each scan contains 30 seconds of data,
# and each slice is one more millimeter vertically. This shall be the working hypothesis given no new information.
# Out:
# ('mm', 'sec')

# %%
mri1.affine  # This relates voxel coordinates to real-world coordinates... somehow

# Update: figured it out. This is a linear transformation matrix. The x and y axes are flipped,
# and the z-axis remains the same. The (90, 91, -71) vector is a translation in 3D space.
# This matrix transforms voxel coordinates to RAS+ coordinates.
# Out:
# array([[ -1.,   0.,   0.,  90.],
#        [  0.,  -1.,   0.,  91.],
#        [  0.,   0.,   1., -72.],
#        [  0.,   0.,   0.,   1.]])

# %% [markdown]
# ## Initital visualization & exploration

# %%
mri1_data.dtype
# Out:
# dtype('<i2')

# %%
mri1_data.shape  # x, y, z, time
# Out:
# (182, 218, 182, 31)

# %%
mri1_data[:, :, 15, 5]  # I think each element is the value to put on each pixel? Is closer to 0 more dark, or more white?
# Out:
# memmap([[ 7,  6,  6, ...,  8,  8,  9],
#         [ 6,  6,  6, ...,  7,  7, 10],
#         [ 6,  5,  5, ...,  7,  7, 10],
#         ...,
#         [11, 11, 11, ...,  7,  9, 11],
#         [11, 11, 11, ...,  6,  7,  8],
#         [11, 11, 12, ...,  6,  6,  6]], dtype=int16)

# %%
np.amax(mri1_data[:, :, 15, 5])
# Out:
# 287

# %%
from nilearn import plotting, datasets

# %%
img = datasets.fetch_localizer_button_task()['tmaps'][0]

# %%
view = plotting.plot_stat_map(img, threshold=2, vmax=4)

# %% [markdown]
# ### Plotting data retrieved from the get_data() method

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 15))
z, t = 15, 5  # time begins with the high-contrast image, so I don't have to worry about 0-indexing.

ax1.imshow(mri1_data[:, :, z, t], cmap='gray')  # z=15 is where full image begins, z=150 is where full image ends

ax2.imshow(mri2_data[:, :, z, t], cmap='gray')

# Why is this only showing an axial view? Are there saggital and coronal views somewhere in this data?

# %%
# TODO: Slider widget that moves through time
# TODO: Slider widget that moves through z-axis

# %%
# Found a class on nib documentation for viewing images
viewer_1 = nib.viewers.OrthoSlicer3D(mri1_data, affine=mri1.affine)  # WHOA there are saggital and coronal sections in this data somewhere

# %% [markdown]
# ### TODO: make a slider widget that lets you scroll through this data

# %% [markdown]
# Scale the data (window) to allow easy viewing of the data and plot time=5 and z slice=15 from each session (and explain why you chose the levels that you did)

# %% [markdown]
# ## Play around to understand exactly how imshow works

# %%
# Play around with numpy to figure out how images work

mri_high_contrast = np.copy(mri1_data[:, :, 15, 0])  # Grab 60th slice to get a full image of the brain
zroes = mri_high_contrast * 0
halves = (np.copy(zroes) + 1) * 100
halves[:, :40] = 0
halves[:, 180:] = 200

plt.imshow(halves, cmap='gray')

# black:white is a range between the minimum value and the maximum value.
# So, if there is a large maximum value, the rest of the image will be skewed.
# Cut out outliers!

# %%
# Get direct information on what the 15th slice at the high-contrast time-point looks like.
# Mean of 72, 75th percentile is 71 -- so there are a tiny amount of massive outliers.
# Because of the image shown above, this means the value determining white will be absurdly high,
# and the image contrast will be way off.

pd.Series(mri1_data[:, :, 15, 0].ravel()).describe()
# Out:
# count    39676.000000
# mean        72.963101
# std        123.135350
# min          0.000000
# 25%         13.000000
# 50%         29.000000
# 75%         71.000000
# max       2126.000000
# dtype: float64

# %% [markdown]
# ## Scale & Plot the Data

# %%
# TODO: scale data
# REMEMBER: first time-point (of the 31 time points) is a high-contrast point prior to testing

plt.hist(mri1_data[:, :, 15, 0].ravel(), bins=256,
         fc='k', ec='k');  # Use first time-point. Most of the interesting stuff is at the peak, which is near 70

# Clip regions above and below peak

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 20))
z, t = 15, 5  # time begins with the high-contrast image, so I don't have to worry about 0-indexing.

ax1.imshow(mri1_data[:, :, z, t], cmap='gray')  # z=15 is where full image begins, z=150 is where full image ends
ax2.imshow(mri2_data[:, :, z, t], cmap='gray')

ax1.set_title('Session 1')
ax2.set_title('Session 2')

# Why is this only showing an axial view? Are there saggital and coronal views somewhere in this data?
# Out:
# Text(0.5,1,'Session 2')

# %% [markdown]
# ## Crop out a brain area, plot that region for each session

# %%
# Cerebellum is fun, and easy to see

z, t = 30, 5  # z=[15, 60] is cerebellum

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 20))

ax1.imshow(mri1_data[30:140, 105:190, z, t], cmap='gray')
ax2.imshow(mri2_data[30:140, 105:190, z, t], cmap='gray')

ax1.set_title('Session 1')
ax2.set_title('Session 2')
# Out:
# Text(0.5,1,'Session 2')

# %% [markdown]
# ## Choose an intensity value at slice 15, return number of pixels above that threshold for each session

# %%
# TODO: write a loop that outputs this information.
# TODO: Figure out how to determine what threshold to use.
# Assuming 'intensity value' is equivalent to 'threshold'

# %% [markdown]
# ## Using threshold, perform first-order analysis

# %%
# TODO: figure out what 'first-order analysis' means.

# %% [markdown]
# ## Train a random forest classifier to differentiate between sessions.

# %% [markdown]
# ### Need out-of-bag error and distribution of cllass conditional posteriors

# %%
# TODO: figure out how random forest classifiers work.
# TODO: learn what out-of-bag error means.
# TODO: learn what a class conditional posterior estimated random forest is.

# %%
from sklearn.ensemble import RandomForestClassifier  # This should be the one
# Read through source code here
# invidual trees available in estimators_
# export_graphvis: for visualizing trees

??RandomForestClassifier
# Out:
# Init signature: RandomForestClassifier(n_estimators=10, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, class_weight=None)
# Source:
# class RandomForestClassifier(ForestClassifier):
#     """A random forest classifier.
#
#     A random forest is a meta estimator that fits a number of decision tree
#     classifiers on various sub-samples of the dataset and use averaging to
#     improve the predictive accuracy and control over-fitting.
#     The sub-sample size is always the same as the original
#     input sample size but the samples are drawn with replacement if
#     `bootstrap=True` (default).
#
#     Read more in the :ref:`User Guide <forest>`.
#
#     Parameters
#     ----------
#     n_estimators : integer, optional (default=10)
# ...
